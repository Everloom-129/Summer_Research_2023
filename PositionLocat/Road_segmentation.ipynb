# %% [markdown]
# # Test dino
# use ipynb to speed up the base line work

# %%
import os
import cv2
import torch
import torchvision
import supervision as sv

import warnings
import numpy as np
from PIL import Image
from glob import glob

import termcolor
import matplotlib.pyplot as plt

from groundingdino.util.inference import Model
from segment_anything import sam_model_registry, SamPredictor
#TODO name!
from groundingdino.util.inference import load_model, load_image, predict, annotate

warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Paths to GroundingDINO and SAM checkpoints
GROUNDING_DINO_CONFIG_PATH = "/root/autodl-tmp/DINO/groundingdino/config/GroundingDINO_SwinT_OGC.py"
GROUNDING_DINO_CHECKPOINT_PATH = "/root/autodl-tmp/DINO/weights/groundingdino_swint_ogc.pth"
model_type = "default"
SAM_CHECKPOINT_PATH = "/root/autodl-tmp/sam_vit_h_4b8939.pth"

# Predict classes and hyper-param for GroundingDINO
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25
NMS_THRESHOLD = 0.8

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)
    
def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)   
    
def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %% [markdown]
# ## functional
# #### Architecture:
#
# 1. dino find road √ （Regieon of interest)
#
# 2. use road's bbox as prompt to use SAM
#
#    text: person, sidewalk, road, vehicle
#
# 3. rule base
#
#    - comparing pixel relationship betweeen person and road, sidewalk
#    - other VQA method to generate text
#
# 4. analyze image sequence, predict behavior
#
#    - question: can I try LLM to do this?
#      - 一些想法，之后会议解释
#
# 5. overall must use video & image

# %%
# Initialize GroundingDINO model
grounding_dino_model = Model(
    model_config_path=GROUNDING_DINO_CONFIG_PATH, 
    model_checkpoint_path=GROUNDING_DINO_CHECKPOINT_PATH, 
    device=DEVICE
)

# Initialize SAM model and predictor
sam = sam_model_registry[model_type](checkpoint=SAM_CHECKPOINT_PATH)
sam.to(device=DEVICE)
sam_predictor = SamPredictor(sam)

# Classes of interest (add as needed)

output_dir = 'DINOmasked'
os.makedirs(output_dir, exist_ok=True)
# Out:
# final text_encoder_type: bert-base-uncased
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import supervision as sv


def display_mask(SAM_masks, image_path,image):
    # Create a new subplot
    output_path = os.path.join(output_dir, image_path)
    plt.figure(figsize=(16,9))

    # Display the original image
    plt.imshow(image)
    plt.axis('off')


    for mask in SAM_masks:
        show_mask(mask, plt.gca(), random_color=True)
    for box in DINO_boxes:
        show_box(box, plt.gca())

    plt.savefig(output_path)
    plt.close()




# Prompting SAM with ROI
def segment_ROI(sam_predictor: SamPredictor, image: np.ndarray, xyxy: np.ndarray):
    sam_predictor.set_image(image)
    result_masks = []
    for box in xyxy:
        masks_np, scores_np, _ = sam_predictor.predict(
        point_coords=None,
        point_labels=None,
        box= box,
        multimask_output=True,
        )
        index = np.argmax(scores_np)
        result_masks.append(masks_np[index])

    return np.array(result_masks)

def detect_road(image_path):
    
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


    image_source, image2 = load_image(image_path)

    TEXT_PROMPT = "road . sidewalk"
    CLASSES = ['road', 'sidewalk']
    

    # detect objects
    detections = grounding_dino_model.predict_with_classes(
        image=image,
        classes = CLASSES,
        box_threshold= BOX_TRESHOLD,
        text_threshold=TEXT_TRESHOLD
    )
    detections.box_area 

    box_annotator = sv.BoxAnnotator()

    labels = [
    f"{CLASSES[class_id]} {confidence:0.2f}" 
    for _, _, confidence, class_id, _ 
    in detections]

    annotated_frame = box_annotator.annotate(scene=image.copy(), detections=detections, labels=labels)
    # %matplotlib inline
    # sv.plot_image(annotated_frame, (16, 16))


    # cv2.imwrite("annotated_image.jpg", annotated_frame)
    
    # NMS post process
    nms_idx = torchvision.ops.nms(
        torch.from_numpy(detections.xyxy), 
        torch.from_numpy(detections.confidence), 
        NMS_THRESHOLD
    ).numpy().tolist()

    detections.xyxy = detections.xyxy[nms_idx]
    detections.confidence = detections.confidence[nms_idx]
    detections.class_id = detections.class_id[nms_idx]

    DINO_boxes = np.array(detections.xyxy)


    SAM_masks = segment_ROI(
        sam_predictor=sam_predictor,
        image= image,
        xyxy= DINO_boxes,
    )

    # plt.figure(figsize=(10, 10))
    # plt.imshow(image)

    # for mask in SAM_masks:
    #     show_mask(mask, plt.gca(), random_color=True)
    # for box in DINO_boxes:
    #     show_box(box, plt.gca())
        
    # plt.axis('off')
    # plt.show()
    # display_mask(SAM_masks,image_path,image)
    output_path = os.path.join(output_dir, image_path)
    plt.figure(figsize=(16,9))

    # Display the original image
    plt.imshow(image)
    plt.axis('off')


    for mask in SAM_masks:
        show_mask(mask, plt.gca(), random_color=True)
    for box in DINO_boxes:
        show_box(box, plt.gca())

    plt.savefig(output_path)
    plt.close()


    return DINO_boxes,labels


# text program to make sure the label works
DINO_boxes,labels = detect_road("input/scene_2.png")
print(DINO_boxes, labels)
# Out:
# [[  1.7368164 187.55162   893.4925    430.34235  ]
#  [351.7953    195.08667   893.7616    429.8313   ]] ['road 0.50', 'sidewalk 0.31']

# %%
result_masks = []
mask = [  1.7368164 ,187.55162,   893.4925 ,   430.34235  ]
score = np.array( [  1.7368164 ,187.55162,   893.4925 ,   430.34235  ])
index = np.argmax(score)
result_masks.append(mask[index])
result_masks
# Out:
# [893.4925]

# %%
DINO_boxes[1]
# Out:
# array([351.7953 , 195.08667, 893.7616 , 429.8313 ], dtype=float32)

# %%
image_dir = "selected"
    
print("Start =====")
i = 1
for filename in os.listdir(image_dir):
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
        image_path = os.path.join(image_dir, filename)
        output_path = os.path.join(output_dir, filename)
        if not os.path.exists(output_path):
            print("Processing: ", i)
            i += 1
            print(f"Image path: {termcolor.colored(os.path.basename(image_path), 'green')}")

            result = detect_road(image_path)
            
            print(f"Detected: {termcolor.colored(result, 'blue')}")
# Out:
# Start =====
# Processing:  1
# Image path: video_0001_0012.png
# Detected: (array([[   4.183899 ,  696.2627   , 1917.4514   , 1010.33154  ],
#        [   2.8311157,  937.5635   , 1917.977    , 1077.463    ]],
#       dtype=float32), ['road 0.75', 'sidewalk 0.42'])
# Processing:  2
# Image path: video_0002_0007.png
# Detected: (array([[   2.9528198,  781.04114  , 1523.0205   , 1000.4623   ],
#        [   4.013916 ,  781.1417   , 1914.7395   , 1073.8596   ],
#        [   3.230835 ,  932.0819   , 1917.1422   , 1076.9109   ]],
#       dtype=float32), ['road 0.39', 'road 0.29', 'road 0.26'])
# Processing:  3
# Image path: video_0003_0004.png
# Detected: (array([[   4.653076 ,  699.9023   , 1915.5515   , 1075.1248   ],
#        [ 281.41516  ,  705.7569   , 1620.6094   ,  973.64496  ],
#        [ 289.2341   ,  777.806    ,  810.494    ,  933.048    ],
#        [   2.6627197,  931.6172   , 1916.9866   , 1076.7948   ]],
#       dtype=float32), ['road 0.42', 'sidewalk 0.34', 'road 0.36', 'sidewalk 0.30'])
# Processing:  4
# Image path: video_0004_0005.png
# Detected: (array([[   3.0351562,  682.0137   , 1916.9797   , 1075.6648   ],
#        [  71.48535  ,  686.5056   , 1911.0571   ,  847.88354  ]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.31', 'sidewalk 0.30'])
# Processing:  5
# Image path: video_0005_0005.png
# Detected: (array([[   2.9728394,  727.85187  , 1916.4648   , 1076.1033   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.36'])
# Processing:  6
# Image path: video_0006_0006.png
# Detected: (array([[   3.1567993,  710.9725   , 1917.1279   , 1074.2771   ]],
#       dtype=float32), ['road 0.68', 'sidewalk 0.26'])
# Processing:  7
# Image path: video_0007_0003.png
# Detected: (array([[3.1431885e+00, 6.6858057e+02, 1.9165675e+03, 1.0759500e+03],
#        [1.0603638e+00, 6.6836310e+02, 9.4379700e+02, 7.8347003e+02],
#        [4.2349854e+00, 6.6851825e+02, 1.9129890e+03, 9.3186688e+02],
#        [1.3302612e+00, 8.7982275e+02, 1.9181328e+03, 1.0767761e+03]],
#       dtype=float32), ['road 0.48', 'sidewalk 0.35', 'sidewalk 0.27', 'road 0.30'])
# Processing:  8
# Image path: video_0008_0004.png
# Detected: (array([[3.4577026e+00, 7.1778162e+02, 1.9163157e+03, 1.0709409e+03],
#        [1.8696899e+00, 8.7777393e+02, 1.9183511e+03, 1.0175459e+03],
#        [4.0823975e+00, 7.1861884e+02, 1.9162639e+03, 9.4258527e+02],
#        [1.5263672e+00, 8.7687640e+02, 1.9182382e+03, 1.0733213e+03]],
#       dtype=float32), ['road 0.40', 'sidewalk 0.28', 'road 0.33', 'sidewalk 0.38', 'road 0.31'])
# Processing:  9
# Image path: video_0009_0001.png
# Detected: (array([[   2.7495728,  658.42957  , 1916.2283   ,  951.92725  ],
#        [   3.543213 ,  658.3783   , 1916.3545   , 1071.7328   ]],
#       dtype=float32), ['road 0.53', 'road 0.26'])
# Processing:  10
# Image path: video_0010_0002.png
# Detected: (array([[2.4429321e+00, 6.4955127e+02, 1.9175659e+03, 9.4953955e+02],
#        [1.3165673e+03, 6.8551495e+02, 1.9186378e+03, 8.0335785e+02],
#        [1.2581787e+00, 6.9867798e+02, 5.5923346e+02, 7.6205103e+02]],
#       dtype=float32), ['road 0.58', 'sidewalk 0.28', 'sidewalk 0.26'])
# Processing:  11
# Image path: video_0011_0009.png
# Detected: (array([[   4.137207 ,  639.8398   , 1917.94     ,  938.7253   ],
#        [   2.8363647,  853.2645   , 1917.0564   , 1076.1427   ]],
#       dtype=float32), ['road 0.62', 'sidewalk 0.39'])
# Processing:  12
# Image path: video_0012_0002.png
# Detected: (array([[1.1340332e+00, 6.4301093e+02, 1.9187085e+03, 9.3818463e+02],
#        [2.9608154e+00, 6.4301990e+02, 1.9172743e+03, 1.0729329e+03]],
#       dtype=float32), ['road 0.35', 'road 0.46'])
# Processing:  13
# Image path: video_0013_0001.png
# Detected: (array([[   4.001465 ,  657.48694  , 1915.6779   , 1070.2778   ],
#        [   3.4360962,  924.807    , 1915.7036   , 1076.4817   ]],
#       dtype=float32), ['road 0.41', 'sidewalk 0.33', 'road 0.37'])
# Processing:  14
# Image path: video_0014_0001.png
# Detected: (array([[   4.1345825,  653.1599   , 1914.9978   ,  939.6216   ],
#        [   2.0748901,  660.94006  , 1465.666    ,  939.42334  ]],
#       dtype=float32), ['road 0.36', 'road 0.35', 'road 0.25'])
# Processing:  15
# Image path: video_0015_0011.png
# Detected: (array([[1.9171143e+00, 6.7350519e+02, 1.3739144e+03, 9.3705463e+02],
#        [3.4471436e+00, 6.2134521e+02, 1.9164526e+03, 9.3891211e+02],
#        [1.0758572e+03, 6.2595282e+02, 1.9172671e+03, 8.9991034e+02]],
#       dtype=float32), ['road 0.47', 'road 0.30', 'road 0.30'])
# Processing:  16
# Image path: video_0016_0006.png
# Detected: (array([[   2.9209595,  642.7161   , 1917.5627   ,  936.28986  ],
#        [   2.182251 ,  861.1511   , 1916.775    , 1076.4314   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.27'])
# Processing:  17
# Image path: video_0017_0008.png
# Detected: (array([[   2.7908936,  639.9284   , 1916.6239   ,  933.2775   ]],
#       dtype=float32), ['road 0.58'])
# Processing:  18
# Image path: video_0018_0009.png
# Detected: (array([[2.7722778e+00, 6.0402673e+02, 1.9172532e+03, 9.4007520e+02],
#        [1.5034790e+00, 7.0092810e+02, 1.2648386e+03, 9.3952161e+02],
#        [3.6311646e+00, 6.0352844e+02, 1.9165537e+03, 1.0703157e+03],
#        [1.0310836e+03, 6.0745081e+02, 1.9173820e+03, 8.9419971e+02]],
#       dtype=float32), ['road 0.41', 'road 0.31', 'road 0.33', 'sidewalk 0.31'])
# Processing:  19
# Image path: video_0019_0014.png
# Detected: (array([[   2.968872 ,  663.2069   , 1916.5607   ,  938.381    ],
#        [   3.9887695,  663.1641   , 1916.154    , 1070.0691   ],
#        [   3.1832886,  864.7967   , 1916.1433   , 1076.027    ]],
#       dtype=float32), ['road 0.52', 'road 0.27', 'sidewalk 0.25'])
# Processing:  20
# Image path: video_0020_0017.png
# Detected: (array([[1038.052   ,  672.82104 , 1918.4299  ,  902.7606  ],
#        [ 646.4732  ,  669.17236 , 1918.8093  ,  904.348   ],
#        [1571.8517  ,  666.4485  , 1919.212   ,  747.178   ],
#        [   6.354004,  675.09283 ,  790.7721  ,  794.1065  ]],
#       dtype=float32), ['road 0.43', 'road 0.30', 'sidewalk 0.29', 'sidewalk 0.29'])
# Processing:  21
# Image path: video_0021_0003.png
# Detected: (array([[   3.4552002,  668.27185  , 1915.8254   , 1074.811    ],
#        [   3.508545 ,  665.0429   , 1908.9498   ,  937.0975   ]],
#       dtype=float32), ['road 0.38', 'road 0.30', 'road 0.37'])
# Processing:  22
# Image path: video_0022_0014.png
# Detected: (array([[   3.8082886,  651.61884  , 1916.5488   ,  936.41364  ],
#        [   2.729309 ,  862.4197   , 1917.1165   , 1073.8368   ],
#        [   4.0255737,  649.6801   , 1916.2427   , 1069.8975   ]],
#       dtype=float32), ['road 0.28', 'sidewalk 0.49', 'road 0.52'])
# Processing:  23
# Image path: video_0023_0005.png
# Detected: (array([[   4.4799194,  629.3579   , 1914.4431   ,  958.15686  ],
#        [   3.973938 ,  623.0858   , 1915.8992   , 1074.6135   ]],
#       dtype=float32), ['road 0.40', 'road 0.37'])
# Processing:  24
# Image path: video_0024_0004.png
# Detected: (array([[   5.0631104,  630.9784   , 1389.5225   ,  922.4326   ],
#        [   4.072693 ,  627.45654  , 1915.8486   , 1073.7988   ]],
#       dtype=float32), ['road 0.42', 'road 0.29'])
# Processing:  25
# Image path: video_0025_0001.png
# Detected: (array([[  11.166321,  647.5477  , 1336.968   ,  912.56616 ]],
#       dtype=float32), ['road 0.55'])
# Processing:  26
# Image path: video_0026_0012.png
# Detected: (array([[   5.0964355,  665.96484  , 1913.796    ,  940.6542   ],
#        [   4.482483 ,  658.87115  , 1915.3989   , 1072.2686   ]],
#       dtype=float32), ['road 0.41', 'road 0.36'])
# Processing:  27
# Image path: video_0027_0002.png
# Detected: (array([[ 578.1932   ,  667.56836  , 1917.7517   ,  979.1604   ],
#        [   2.3087769,  920.50385  , 1917.261    , 1077.3088   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.27'])
# Processing:  28
# Image path: video_0028_0004.png
# Detected: (array([[   1.5299377,  858.9041   ,  905.8391   , 1077.6472   ],
#        [ 407.698    ,  862.72424  , 1517.6587   , 1077.3414   ]],
#       dtype=float32), ['road 0.47', 'sidewalk 0.64'])
# Processing:  29
# Image path: video_0029_0016.png
# Detected: (array([[   2.3546143,  757.08844  , 1377.8921   , 1068.3287   ],
#        [   4.7994385,  759.30743  , 1368.7385   ,  995.98224  ],
#        [1048.0376   ,  700.1469   , 1916.8613   ,  961.6032   ]],
#       dtype=float32), ['road 0.41', 'road 0.29', 'sidewalk 0.28'])
# Processing:  30
# Image path: video_0030_0005.png
# Detected: (array([[1.5257874e+00, 7.6158386e+02, 7.4044702e+02, 1.0033750e+03],
#        [3.4108368e+02, 7.4368146e+02, 1.6396719e+03, 9.8239069e+02],
#        [2.9386597e+00, 9.3375183e+02, 1.9172678e+03, 1.0777307e+03],
#        [4.3145752e+00, 7.4280994e+02, 1.6483485e+03, 1.0029474e+03]],
#       dtype=float32), ['sidewalk 0.48', 'road 0.45', 'sidewalk 0.28', 'road 0.26'])
# Processing:  31
# Image path: video_0031_0006.png
# Detected: (array([[1.3105520e+03, 7.0262640e+02, 1.9182722e+03, 9.4802655e+02],
#        [1.3506775e+00, 8.0335443e+02, 6.8663660e+02, 9.0038837e+02],
#        [1.2478638e+00, 7.3166132e+02, 1.3761018e+03, 9.0086920e+02]],
#       dtype=float32), ['road 0.48', 'sidewalk 0.30', 'sidewalk 0.26'])
# Processing:  32
# Image path: video_0032_0002.png
# Detected: (array([[   2.7404785,  647.4797   , 1917.7198   ,  953.43756  ],
#        [   2.7589722,  851.2171   , 1916.218    , 1076.339    ]],
#       dtype=float32), ['road 0.68', 'sidewalk 0.27'])
# Processing:  33
# Image path: video_0033_0001.png
# Detected: (array([[   3.0964966,  646.484    , 1476.7571   ,  971.0808   ],
#        [   3.6779785,  644.36646  , 1916.1261   , 1072.9381   ],
#        [   3.5662842,  640.1267   , 1913.2253   ,  976.05615  ]],
#       dtype=float32), ['road 0.36', 'road 0.36', 'road 0.33'])
# Processing:  34
# Image path: video_0034_0011.png
# Detected: (array([[  10.800964,  666.8303  , 1447.0242  ,  934.36    ]],
#       dtype=float32), ['road 0.54'])
# Processing:  35
# Image path: video_0035_0002.png
# Detected: (array([[1.5464783e+00, 6.6743927e+02, 7.8428174e+02, 9.4036578e+02],
#        [3.2319946e+00, 6.4491138e+02, 1.9169426e+03, 9.3640259e+02],
#        [8.4111127e+02, 6.4342090e+02, 1.9172949e+03, 8.9415076e+02],
#        [4.1441650e+00, 6.4847095e+02, 1.9161561e+03, 1.0729313e+03],
#        [2.8428955e+00, 8.6798505e+02, 1.9167885e+03, 1.0756849e+03]],
#       dtype=float32), ['road 0.45', 'sidewalk 0.29', 'road 0.38', 'road 0.29', 'sidewalk 0.25'])
# Processing:  36
# Image path: video_0036_0004.png
# Detected: (array([[   3.6530151,  632.0088   , 1916.394    , 1074.2206   ],
#        [   2.0237427,  671.1744   ,  787.49567  ,  750.33734  ],
#        [   6.985779 ,  652.3793   , 1410.0518   ,  932.3357   ],
#        [   3.6774292,  633.67773  , 1915.7483   ,  935.46985  ]],
#       dtype=float32), ['road 0.43', 'sidewalk 0.38', 'road 0.28', 'road 0.27'])
# Processing:  37
# Image path: video_0037_0005.png
# Detected: (array([[   2.7042236,  730.98065  , 1918.0131   , 1077.1779   ],
#        [1082.463    ,  767.4186   , 1776.8002   ,  887.5282   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.26'])
# Processing:  38
# Image path: video_0038_0010.png
# Detected: (array([[6.2254840e+02, 7.7411633e+02, 1.4425234e+03, 1.0192897e+03],
#        [1.5755615e+00, 9.5721375e+02, 1.9184945e+03, 1.0781709e+03],
#        [3.3670654e+00, 7.7700745e+02, 1.9154636e+03, 1.0770585e+03]],
#       dtype=float32), ['road 0.45', 'road 0.30', 'sidewalk 0.32'])
# Processing:  39
# Image path: video_0039_0001.png
# Detected: (array([[   3.30719  ,  695.8859   , 1917.2046   , 1062.2427   ],
#        [ 826.7218   ,  790.14374  , 1320.6888   ,  860.2681   ],
#        [   2.8756104,  966.5662   , 1917.5204   , 1077.5616   ]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.36', 'sidewalk 0.26'])
# Processing:  40
# Image path: video_0040_0002.png
# Detected: (array([[   3.9569702,  784.8363   , 1915.427    , 1077.1357   ],
#        [   2.4576416,  969.0478   , 1917.8251   , 1078.2451   ],
#        [ 583.40894  ,  789.8923   , 1448.7491   , 1033.5415   ]],
#       dtype=float32), ['road 0.43', 'road 0.28', 'sidewalk 0.29'])
# Processing:  41
# Image path: video_0041_0004.png
# Detected: (array([[   4.152893 ,  644.0303   , 1916.419    , 1069.8613   ],
#        [   3.7268677,  653.01465  , 1680.0647   ,  782.2136   ]],
#       dtype=float32), ['road 0.56', 'sidewalk 0.37'])
# Processing:  42
# Image path: video_0042_0005.png
# Detected: (array([[1.6498413e+00, 7.2481305e+02, 1.9181016e+03, 9.9909271e+02],
#        [2.8038330e+00, 9.3148450e+02, 1.9168456e+03, 1.0770555e+03],
#        [4.0014648e+00, 7.2385541e+02, 1.9162078e+03, 1.0687286e+03]],
#       dtype=float32), ['road 0.30', 'sidewalk 0.37', 'road 0.50'])
# Processing:  43
# Image path: video_0043_0007.png
# Detected: (array([[   2.6989746,  624.1123   , 1284.5607   ,  936.02234  ],
#        [   2.2145996,  582.1415   , 1917.3358   ,  938.78455  ],
#        [   3.220337 ,  588.958    , 1916.6158   , 1073.478    ]],
#       dtype=float32), ['road 0.36', 'road 0.29', 'road 0.35'])
# Processing:  44
# Image path: video_0044_0002.png
# Detected: (array([[   2.4226685,  632.8386   , 1498.1411   ,  944.6123   ],
#        [1247.0543   ,  614.0763   , 1918.0795   ,  892.0122   ]],
#       dtype=float32), ['sidewalk 0.33', 'road 0.50'])
# Processing:  45
# Image path: video_0045_0005.png
# Detected: (array([[2.9573364e+00, 6.3074524e+02, 1.9171277e+03, 9.3637317e+02],
#        [1.6503296e+00, 8.6983240e+02, 1.9174241e+03, 1.0774320e+03]],
#       dtype=float32), ['road 0.53', 'sidewalk 0.29'])
# Processing:  46
# Image path: video_0046_0002.png
# Detected: (array([[   3.5665894,  655.4899   , 1916.5815   , 1075.2981   ],
#        [   2.7920532,  659.51465  , 1454.419    ,  939.12256  ],
#        [   3.857483 ,  655.2318   , 1915.2712   ,  939.9592   ]],
#       dtype=float32), ['road 0.45', 'road 0.29', 'road 0.28'])
# Processing:  47
# Image path: video_0047_0003.png
# Detected: (array([[   2.5343018,  666.79205  , 1917.6808   ,  974.8957   ],
#        [   3.409668 ,  665.9895   , 1916.425    ,  799.8037   ]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.29', 'sidewalk 0.25'])
# Processing:  48
# Image path: video_0048_0001.png
# Detected: (array([[   3.5941162,  692.9042   , 1916.4075   ,  984.433    ],
#        [   2.913086 ,  886.0502   , 1916.73     , 1076.2157   ],
#        [   3.8764038,  693.59314  , 1915.8169   , 1071.2661   ]],
#       dtype=float32), ['road 0.28', 'sidewalk 0.40', 'road 0.50'])
# Processing:  49
# Image path: video_0049_0001.png
# Detected: (array([[3.9824219e+00, 7.3752234e+02, 1.9144812e+03, 1.0715302e+03],
#        [1.4230347e+00, 7.4183667e+02, 1.4768984e+03, 1.0189636e+03]],
#       dtype=float32), ['road 0.38', 'road 0.31', 'road 0.31'])
# Processing:  50
# Image path: video_0050_0005.png
# Detected: (array([[   1.9505005,  699.7007   , 1864.5442   , 1007.6636   ],
#        [ 704.0311   ,  702.152    , 1859.7228   ,  887.3446   ],
#        [ 702.27454  ,  713.6814   , 1426.393    ,  885.2667   ]],
#       dtype=float32), ['road 0.42', 'sidewalk 0.26', 'road 0.27', 'sidewalk 0.26'])
# Processing:  51
# Image path: video_0051_0006.png
# Detected: (array([[   3.6953125,  695.14105  , 1915.9153   , 1075.4952   ]],
#       dtype=float32), ['road 0.60'])
# Processing:  52
# Image path: video_0052_0001.png
# Detected: (array([[   2.4753418,  740.36633  , 1642.4349   , 1040.967    ],
#        [   2.8886108,  723.1458   , 1916.2534   , 1059.955    ],
#        [1213.5337   ,  795.33167  , 1639.47     ,  917.4147   ]],
#       dtype=float32), ['road 0.37', 'road 0.39', 'sidewalk 0.32'])
# Processing:  53
# Image path: video_0053_0004.png
# Detected: (array([[ 558.4002  ,  816.0378  ,  838.4781  ,  903.12897 ],
#        [   4.494873,  781.59906 , 1916.685   , 1075.9304  ],
#        [ 338.04608 ,  781.1195  , 1908.0286  , 1030.7168  ]],
#       dtype=float32), ['sidewalk 0.53', 'road 0.46', 'road 0.33'])
# Processing:  54
# Image path: video_0054_0007.png
# Detected: (array([[   2.850769 ,  659.59143  , 1917.71     ,  948.4901   ],
#        [1157.2681   ,  657.92505  , 1918.459    ,  783.7743   ],
#        [   1.9575195,  701.07806  ,  582.32446  ,  792.22845  ]],
#       dtype=float32), ['road 0.58', 'sidewalk 0.27', 'sidewalk 0.39'])
# Processing:  55
# Image path: video_0055_0005.png
# Detected: (array([[ 863.76575  ,  597.7507   , 1818.3866   ,  750.5247   ],
#        [   2.3693848,  588.33124  , 1917.776    ,  941.30255  ],
#        [   3.307495 ,  590.25037  , 1916.7882   , 1072.7465   ]],
#       dtype=float32), ['road 0.36', 'road 0.39', 'road 0.38'])
# Processing:  56
# Image path: video_0056_0002.png
# Detected: (array([[   3.1359253,  649.6803   , 1917.1794   ,  938.5      ],
#        [   3.057129 ,  864.4748   , 1915.279    ,  998.79205  ],
#        [   3.232788 ,  861.61456  , 1916.045    , 1074.3195   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.32', 'sidewalk 0.37'])
# Processing:  57
# Image path: video_0057_0003.png
# Detected: (array([[   5.982361 ,  645.73987  , 1490.4836   ,  957.5381   ],
#        [   4.1830444,  641.3661   , 1915.3777   , 1072.8622   ]],
#       dtype=float32), ['road 0.26', 'road 0.47'])
# Processing:  58
# Image path: video_0058_0004.png
# Detected: (array([[   2.8482666,  621.8527   , 1917.3667   ,  940.65497  ],
#        [   3.3031616,  614.66693  , 1916.7607   , 1072.1384   ]],
#       dtype=float32), ['road 0.35', 'road 0.44'])
# Processing:  59
# Image path: video_0059_0003.png
# Detected: (array([[   2.8930664,  734.8756   , 1439.4857   , 1015.5908   ],
#        [1086.6162   ,  745.94635  , 1851.3845   ,  951.3278   ]],
#       dtype=float32), ['road 0.62', 'sidewalk 0.54'])
# Processing:  60
# Image path: video_0060_0003.png
# Detected: (array([[1.9062500e+00, 5.7385980e+02, 1.9174539e+03, 9.2735980e+02],
#        [3.0767822e+00, 8.2498962e+02, 1.9162821e+03, 1.0760710e+03]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.27'])
# Processing:  61
# Image path: video_0061_0001.png
# Detected: (array([[ 625.1009  ,  404.36926 , 1278.6482  ,  660.8635  ],
#        [ 154.6261  ,  398.147   ,  821.6936  ,  667.37317 ],
#        [  32.550232,  398.3609  , 1279.5586  ,  678.2187  ]],
#       dtype=float32), ['sidewalk 0.55', 'road 0.34', 'road 0.29', 'road 0.29'])
# Processing:  62
# Image path: video_0062_0004.png
# Detected: (array([[1066.8514   ,  404.68176  , 1278.9318   ,  649.969    ],
#        [   2.8292847,  412.3516   , 1148.082    ,  644.07983  ],
#        [ 982.303    ,  404.4309   , 1279.5168   ,  650.68604  ]],
#       dtype=float32), ['road 0.28', 'sidewalk 0.29', 'road 0.32', 'road 0.25'])
# Processing:  63
# Image path: video_0063_0002.png
# Detected: (array([[ 668.7473 ,  434.15363, 1278.5691 ,  654.03973],
#        [ 262.94678,  422.23373,  827.10156,  661.7846 ]], dtype=float32), ['sidewalk 0.58', 'road 0.55'])
# Processing:  64
# Image path: video_0064_0010.png
# Detected: (array([[2.5159302e+00, 4.6283002e+02, 1.2773413e+03, 6.6708661e+02],
#        [8.4469604e-01, 4.6335843e+02, 7.1729285e+02, 5.1598431e+02],
#        [1.6556396e+00, 4.6249902e+02, 1.2781659e+03, 5.2013171e+02]],
#       dtype=float32), ['road 0.47', 'sidewalk 0.26', 'sidewalk 0.28'])
# Processing:  65
# Image path: video_0065_0004.png
# Detected: (array([[   1.5458374,  468.84583  , 1278.4893   ,  547.2893   ],
#        [   2.425293 ,  470.4837   , 1277.5085   ,  668.9047   ],
#        [   1.8505859,  512.35223  , 1278.1592   ,  662.616    ]],
#       dtype=float32), ['road 0.43', 'sidewalk 0.54', 'road 0.28'])
# Processing:  66
# Image path: video_0066_0011.png
# Detected: (array([[   1.4510803,  407.14813  ,  872.06995  ,  710.5318   ],
#        [   2.145935 ,  402.13043  , 1276.832    ,  710.73517  ],
#        [ 629.6371   ,  413.76733  , 1278.235    ,  656.67957  ]],
#       dtype=float32), ['road 0.38', 'road 0.34', 'road 0.33', 'road 0.27'])
# Processing:  67
# Image path: video_0067_0005.png
# Detected: (array([[   1.9828491,  407.6128   , 1277.8579   ,  713.1471   ],
#        [ 662.06244  ,  391.52493  , 1255.9065   ,  449.5507   ]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.33'])
# Processing:  68
# Image path: video_0068_0003.png
# Detected: (array([[   2.3601685,  397.89703  , 1276.4546   ,  712.9449   ],
#        [   5.579773 ,  398.11627  , 1099.3047   ,  656.94977  ]],
#       dtype=float32), ['road 0.49', 'road 0.30'])
# Processing:  69
# Image path: video_0069_0002.png
# Detected: (array([[2.0285645e+00, 3.9793683e+02, 1.2779982e+03, 7.1443597e+02],
#        [7.2009277e-01, 4.0418753e+02, 6.4662854e+02, 5.4207678e+02],
#        [8.3565729e+02, 4.1069070e+02, 1.2764297e+03, 4.7662985e+02]],
#       dtype=float32), ['road 0.67', 'sidewalk 0.44', 'sidewalk 0.26'])
# Processing:  70
# Image path: video_0070_0001.png
# Detected: (array([[   2.5350342,  389.6889   , 1277.2426   ,  713.5445   ],
#        [1005.9084   ,  460.88272  , 1278.1276   ,  634.2012   ],
#        [   4.526184 ,  391.99084  , 1274.7019   ,  646.0193   ]],
#       dtype=float32), ['road 0.51', 'sidewalk 0.31', 'road 0.29'])
# Processing:  71
# Image path: video_0071_0011.png
# Detected: (array([[   3.4212646,  660.28564  , 1910.1113   , 1075.8309   ],
#        [   2.7758179,  667.25256  ,  834.2928   ,  751.32544  ]],
#       dtype=float32), ['road 0.47', 'road 0.33', 'sidewalk 0.35'])
# Processing:  72
# Image path: video_0072_0004.png
# Detected: (array([[3.0987549e+00, 6.6448029e+02, 1.9171249e+03, 1.0774846e+03],
#        [8.3407593e-01, 6.9167877e+02, 7.4693591e+02, 8.6152374e+02]],
#       dtype=float32), ['road 0.77', 'sidewalk 0.47'])
# Processing:  73
# Image path: video_0073_0002.png
# Detected: (array([[   5.19751,  732.8263 , 1914.9446 , 1076.9392 ],
#        [ 869.03864,  733.83374, 1918.5178 , 1013.3235 ]], dtype=float32), ['road 0.73', 'sidewalk 0.35', 'sidewalk 0.40'])
# Processing:  74
# Image path: video_0074_0006.png
# Detected: (array([[   6.617859,  702.18207 , 1916.4326  , 1077.0093  ],
#        [ 485.65796 ,  707.54034 , 1918.0508  , 1076.1548  ]],
#       dtype=float32), ['road 0.50', 'road 0.28'])
# Processing:  75
# Image path: video_0075_0001.png
# Detected: (array([[2.8218994e+00, 6.7788696e+02, 1.9175988e+03, 1.0766868e+03],
#        [1.1401062e+00, 6.8926520e+02, 7.3829846e+02, 8.5233905e+02],
#        [8.4802985e+02, 6.9185803e+02, 1.4045276e+03, 7.7437939e+02]],
#       dtype=float32), ['road 0.76', 'sidewalk 0.36', 'sidewalk 0.31'])
# Processing:  76
# Image path: video_0076_0001.png
# Detected: (array([[   3.2161255,  685.0379   , 1915.3796   , 1076.2644   ],
#        [   1.9959717,  693.5691   , 1227.4904   , 1076.5594   ]],
#       dtype=float32), ['road 0.40', 'road 0.38'])
# Processing:  77
# Image path: video_0077_0003.png
# Detected: (array([[   7.3358154,  699.0005   , 1915.8212   , 1075.074    ],
#        [ 635.10803  ,  712.2175   , 1916.3947   , 1046.7504   ],
#        [ 659.1479   ,  691.81744  , 1915.3687   ,  755.18036  ]],
#       dtype=float32), ['road 0.34', 'road 0.38', 'sidewalk 0.28'])
# Processing:  78
# Image path: video_0078_0007.png
# Detected: (array([[2.6720581e+00, 6.4571429e+02, 1.9177495e+03, 1.0764935e+03],
#        [8.8876880e+02, 6.4810388e+02, 1.9166099e+03, 7.5923950e+02],
#        [1.5428467e+00, 6.4050446e+02, 7.2434363e+02, 8.3430328e+02]],
#       dtype=float32), ['road 0.79', 'sidewalk 0.43', 'sidewalk 0.29'])
# Processing:  79
# Image path: video_0079_0001.png
# Detected: (array([[4.2727661e+00, 6.8916675e+02, 1.9160354e+03, 1.0756721e+03],
#        [2.3447571e+00, 6.9264246e+02, 8.0697192e+02, 8.5028577e+02],
#        [1.4191284e+00, 7.0618481e+02, 6.7852637e+02, 8.4865002e+02]],
#       dtype=float32), ['road 0.72', 'sidewalk 0.34', 'sidewalk 0.27'])
# Processing:  80
# Image path: video_0080_0009.png
# Detected: (array([[3.3684692e+00, 5.0207684e+02, 1.9174797e+03, 1.0592634e+03],
#        [1.9938965e+00, 5.4174091e+02, 6.1926544e+02, 7.0779950e+02],
#        [1.6803284e+00, 5.3598041e+02, 6.8662939e+02, 7.9373932e+02]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.47', 'sidewalk 0.28'])
# Processing:  81
# Image path: video_0081_0002.png
# Detected: (array([[   3.1741943,  500.2082   , 1916.6038   , 1049.1653   ],
#        [ 793.4423   ,  504.68292  , 1799.6787   ,  575.4976   ]],
#       dtype=float32), ['road 0.51', 'sidewalk 0.32', 'road 0.29'])
# Processing:  82
# Image path: video_0082_0006.png
# Detected: (array([[1.5104370e+00, 6.8239258e+02, 1.4917449e+03, 1.0761810e+03],
#        [6.7972699e+02, 6.8079907e+02, 1.9172207e+03, 1.0704480e+03],
#        [4.1030884e+00, 6.7823956e+02, 1.9151194e+03, 1.0760275e+03],
#        [6.9187952e+02, 6.8251111e+02, 1.9152374e+03, 9.9675549e+02]],
#       dtype=float32), ['road 0.45', 'road 0.32', 'sidewalk 0.42', 'sidewalk 0.26'])
# Processing:  83
# Image path: video_0083_0002.png
# Detected: (array([[2.4924927e+00, 6.3647607e+02, 1.9170740e+03, 1.0764985e+03],
#        [9.8611450e-01, 6.3949500e+02, 8.0040515e+02, 8.4092969e+02],
#        [9.8751459e+02, 6.1400513e+02, 1.9186663e+03, 8.4561206e+02]],
#       dtype=float32), ['road 0.74', 'sidewalk 0.46', 'road 0.28'])
# Processing:  84
# Image path: video_0084_0008.png
# Detected: (array([[3.2207031e+00, 6.7443970e+02, 1.9173165e+03, 1.0762760e+03],
#        [1.6656799e+00, 6.8167773e+02, 7.5764038e+02, 8.7358838e+02],
#        [8.8033655e+02, 6.5911481e+02, 1.9154657e+03, 7.8493573e+02]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.45', 'sidewalk 0.37'])
# Processing:  85
# Image path: video_0085_0006.png
# Detected: (array([[ 433.0108 ,  740.79944, 1916.5281 , 1075.534  ],
#        [ 437.24768,  729.9867 , 1915.3016 ,  818.38135]], dtype=float32), ['road 0.62', 'sidewalk 0.33'])
# Processing:  86
# Image path: video_0086_0004.png
# Detected: (array([[   8.726379,  725.14264 , 1579.1711  , 1077.0544  ],
#        [   4.228119,  745.8127  ,  812.1041  ,  988.9279  ],
#        [ 182.7456  ,  752.44476 ,  805.541   ,  966.5075  ]],
#       dtype=float32), ['sidewalk 0.39', 'road 0.34', 'road 0.42', 'sidewalk 0.25', 'sidewalk 0.28'])
# Processing:  87
# Image path: video_0087_0008.png
# Detected: (array([[   3.1481323,  655.2324   , 1916.7131   , 1076.9954   ],
#        [   2.3180847,  663.4792   ,  712.00854  ,  799.2155   ],
#        [ 989.0002   ,  654.89777  , 1917.9338   ,  930.45184  ]],
#       dtype=float32), ['road 0.72', 'sidewalk 0.31', 'sidewalk 0.34'])
# Processing:  88
# Image path: video_0088_0003.png
# Detected: (array([[3.0654907e+00, 6.5604065e+02, 1.9176360e+03, 1.0689808e+03],
#        [1.3694305e+00, 6.5471313e+02, 4.5827930e+02, 7.2726221e+02]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.50'])
# Processing:  89
# Image path: video_0089_0008.png
# Detected: (array([[1194.7319  ,  747.1965  , 1917.5076  , 1047.4377  ],
#        [   3.786255,  693.3085  , 1915.7854  , 1075.0334  ],
#        [   2.460144,  702.217   , 1179.9097  , 1069.9666  ],
#        [ 909.7433  ,  707.9591  , 1917.2484  , 1069.7975  ]],
#       dtype=float32), ['road 0.36', 'sidewalk 0.37', 'sidewalk 0.31', 'road 0.31', 'sidewalk 0.29'])
# Processing:  90
# Image path: video_0090_0006.png
# Detected: (array([[1.2770386e+00, 6.8468335e+02, 1.8857869e+03, 1.0753162e+03]],
#       dtype=float32), ['road 0.59'])
# Processing:  91
# Image path: video_0091_0002.png
# Detected: (array([[   3.5639038,  784.71484  , 1915.1472   , 1076.3345   ],
#        [1193.2025   ,  798.36884  , 1916.4706   , 1076.6505   ]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.33'])
# Processing:  92
# Image path: video_0092_0005.png
# Detected: (array([[   2.574829,  747.958   , 1917.044   , 1077.1548  ],
#        [1317.1097  ,  765.9608  , 1917.8563  ,  820.78467 ]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.31'])
# Processing:  93
# Image path: video_0093_0001.png
# Detected: (array([[ 761.7859,  714.5325, 1917.0757, 1075.66  ]], dtype=float32), ['road 0.57', 'sidewalk 0.25'])
# Processing:  94
# Image path: video_0094_0007.png
# Detected: (array([[1.6676636e+00, 6.9353711e+02, 1.4248069e+03, 1.0769185e+03],
#        [1.1985779e+03, 7.5331165e+02, 1.9188875e+03, 1.0736703e+03],
#        [3.4278870e+00, 6.9573499e+02, 7.6952686e+02, 7.7450269e+02],
#        [3.7920532e+00, 6.9128760e+02, 1.9155137e+03, 1.0759890e+03],
#        [4.1694946e+00, 6.6032831e+02, 7.6925165e+02, 7.7352496e+02]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.39', 'sidewalk 0.26', 'road 0.27', 'sidewalk 0.27'])
# Processing:  95
# Image path: video_0095_0003.png
# Detected: (array([[   3.446045,  623.50806 , 1916.3845  , 1063.352   ]],
#       dtype=float32), ['road 0.52'])
# Processing:  96
# Image path: video_0096_0006.png
# Detected: (array([[2.7368164e+00, 7.2307782e+02, 1.9172753e+03, 1.0766545e+03],
#        [1.2389526e+00, 7.2300964e+02, 7.0544824e+02, 9.2650342e+02],
#        [8.6400244e+02, 7.2058606e+02, 1.9086018e+03, 8.7468616e+02]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.39', 'sidewalk 0.38'])
# Processing:  97
# Image path: video_0097_0006.png
# Detected: (array([[3.0244141e+00, 6.8651703e+02, 1.9177501e+03, 1.0768247e+03],
#        [1.6075745e+00, 6.9636432e+02, 6.0566602e+02, 9.0277435e+02]],
#       dtype=float32), ['road 0.82', 'sidewalk 0.37'])
# Processing:  98
# Image path: video_0098_0001.png
# Detected: (array([[   3.7822266,  642.744    , 1914.6615   , 1075.8821   ],
#        [   2.1447144,  659.9815   ,  720.2355   ,  803.9799   ],
#        [1376.2505   ,  654.4134   , 1918.5337   , 1030.5991   ]],
#       dtype=float32), ['road 0.40', 'sidewalk 0.36', 'sidewalk 0.35', 'road 0.36', 'road 0.27'])
# Processing:  99
# Image path: video_0099_0005.png
# Detected: (array([[   3.0718384,  705.4586   , 1916.2898   , 1077.0372   ]],
#       dtype=float32), ['road 0.65'])
# Processing:  100
# Image path: video_0100_0008.png
# Detected: (array([[   3.0563354,  678.67456  , 1916.9438   , 1075.8469   ],
#        [1007.8938   ,  707.2188   , 1916.4265   , 1049.9202   ],
#        [1037.5256   ,  726.8389   , 1653.5083   ,  906.3195   ]],
#       dtype=float32), ['road 0.67', 'sidewalk 0.31', 'sidewalk 0.31'])
# Processing:  101
# Image path: video_0101_0005.png
# Detected: (array([[ 322.3708 ,  762.7815 , 1916.9033 , 1073.6151 ],
#        [ 268.8927 ,  699.49384, 1916.4327 ,  847.3288 ]], dtype=float32), ['road 0.70', 'sidewalk 0.27'])
# Processing:  102
# Image path: video_0102_0002.png
# Detected: (array([[   2.831421,  739.3183  , 1917.3057  , 1076.9783  ],
#        [   6.480957,  732.0492  ,  655.9013  ,  795.42896 ]],
#       dtype=float32), ['road 0.74', 'sidewalk 0.26'])
# Processing:  103
# Image path: video_0103_0012.png
# Detected: (array([[3.1366577e+00, 6.7798596e+02, 1.9172034e+03, 1.0766373e+03],
#        [1.5519104e+00, 7.3445758e+02, 7.0087976e+02, 9.1655768e+02]],
#       dtype=float32), ['road 0.80', 'sidewalk 0.55'])
# Processing:  104
# Image path: video_0104_0003.png
# Detected: (array([[   3.3255005,  742.0493   , 1917.0403   , 1076.66     ]],
#       dtype=float32), ['road 0.65'])
# Processing:  105
# Image path: video_0105_0006.png
# Detected: (array([[   2.8243408,  688.47314  , 1917.8014   , 1076.903    ]],
#       dtype=float32), ['road 0.79'])
# Processing:  106
# Image path: video_0106_0003.png
# Detected: (array([[   3.5723877,  703.25806  , 1916.1104   , 1067.7994   ],
#        [ 790.1679   ,  844.64764  , 1353.2415   ,  933.6326   ],
#        [ 780.86383  ,  780.7072   , 1914.0708   , 1047.6622   ],
#        [ 789.34467  ,  782.9159   , 1854.6587   ,  938.6647   ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.26', 'sidewalk 0.27', 'sidewalk 0.26'])
# Processing:  107
# Image path: video_0107_0001.png
# Detected: (array([[2.6367188e+00, 6.5448438e+02, 1.9169271e+03, 1.0744554e+03],
#        [8.6170563e+02, 6.8035638e+02, 1.0143315e+03, 7.4785236e+02],
#        [1.4527588e+00, 6.5590759e+02, 1.2452422e+03, 1.0537134e+03]],
#       dtype=float32), ['road 0.52', 'sidewalk 0.33', 'road 0.30', 'road 0.25'])
# Processing:  108
# Image path: video_0108_0006.png
# Detected: (array([[3.2678833e+00, 6.5110535e+02, 1.9172341e+03, 1.0772181e+03],
#        [1.1653442e+00, 6.9172571e+02, 7.4652148e+02, 8.7874805e+02]],
#       dtype=float32), ['road 0.75', 'sidewalk 0.49'])
# Processing:  109
# Image path: video_0109_0011.png
# Detected: (array([[   2.9087524,  702.31964  , 1917.7869   , 1077.0789   ]],
#       dtype=float32), ['road 0.80'])
# Processing:  110
# Image path: video_0110_0003.png
# Detected: (array([[3.1478271e+00, 6.8563037e+02, 1.9166448e+03, 1.0767676e+03],
#        [9.9697876e-01, 6.4487115e+02, 7.4850366e+02, 9.1164728e+02],
#        [3.2646484e+00, 6.8741919e+02, 1.3942362e+03, 1.0769263e+03]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.44', 'road 0.27'])
# Processing:  111
# Image path: video_0111_0008.png
# Detected: (array([[   2.6295776,  693.0381   , 1917.8198   , 1076.915    ]],
#       dtype=float32), ['road 0.78'])
# Processing:  112
# Image path: video_0112_0007.png
# Detected: (array([[3.2676392e+00, 5.6390503e+02, 1.9165510e+03, 1.0672740e+03],
#        [1.1697693e+00, 6.3923511e+02, 7.1326660e+02, 8.5086560e+02]],
#       dtype=float32), ['road 0.81', 'sidewalk 0.48'])
# Processing:  113
# Image path: video_0113_0005.png
# Detected: (array([[3.7912598e+00, 5.9170038e+02, 1.9169895e+03, 1.0703577e+03],
#        [1.8296509e+00, 6.3263611e+02, 6.3710272e+02, 8.0591711e+02],
#        [9.3704218e+02, 6.2378674e+02, 1.2899910e+03, 7.0875183e+02]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.33', 'sidewalk 0.34'])
# Processing:  114
# Image path: video_0114_0004.png
# Detected: (array([[3.3952026e+00, 5.0711642e+02, 1.9175549e+03, 1.0333953e+03],
#        [1.1260071e+00, 5.2380652e+02, 5.8773499e+02, 7.1748206e+02],
#        [7.3378894e+02, 5.0486032e+02, 1.7200800e+03, 5.9446997e+02]],
#       dtype=float32), ['road 0.74', 'sidewalk 0.47', 'sidewalk 0.36'])
# Processing:  115
# Image path: video_0115_0008.png
# Detected: (array([[2.6846924e+00, 7.2366235e+02, 1.9159032e+03, 1.0774369e+03],
#        [1.5376892e+00, 7.2251691e+02, 7.4403101e+02, 9.0367804e+02]],
#       dtype=float32), ['road 0.63', 'sidewalk 0.60'])
# Processing:  116
# Image path: video_0116_0002.png
# Detected: (array([[  11.189453 ,  712.8372   , 1167.8463   , 1077.0681   ],
#        [   5.5562744,  717.99915  , 1915.9802   , 1076.3253   ],
#        [ 843.52344  ,  726.61505  , 1900.4932   ,  802.99274  ],
#        [ 843.008    ,  727.62976  , 1553.2795   ,  800.0925   ]],
#       dtype=float32), ['road 0.34', 'road 0.44', 'sidewalk 0.28', 'sidewalk 0.29', 'sidewalk 0.27'])
# Processing:  117
# Image path: video_0117_0005.png
# Detected: (array([[  11.775269,  622.34155 , 1916.5952  , 1072.5347  ],
#        [  45.217102,  625.9807  , 1123.1218  ,  803.27454 ]],
#       dtype=float32), ['road 0.54', 'road 0.25'])
# Processing:  118
# Image path: video_0118_0006.png
# Detected: (array([[   3.4104614,  702.7096   , 1917.0698   , 1076.7069   ],
#        [   3.9145508,  694.14746  , 1905.3757   ,  848.87366  ]],
#       dtype=float32), ['road 0.47', 'road 0.30', 'sidewalk 0.39'])
# Processing:  119
# Image path: video_0119_0004.png
# Detected: (array([[2.6946411e+00, 5.6006451e+02, 1.9178062e+03, 1.0691826e+03],
#        [1.8604736e+00, 5.9075061e+02, 7.1363196e+02, 8.0725513e+02]],
#       dtype=float32), ['road 0.80', 'sidewalk 0.47'])
# Processing:  120
# Image path: video_0120_0003.png
# Detected: (array([[   2.783142 ,  587.7175   , 1917.7622   , 1074.5428   ],
#        [   2.7801208,  583.68097  ,  701.00195  ,  801.8807   ],
#        [1014.9783   ,  591.90576  , 1919.331    ,  841.70154  ],
#        [1284.7369   ,  624.0429   , 1919.0209   ,  841.8145   ]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.32', 'sidewalk 0.34', 'sidewalk 0.31'])
# Processing:  121
# Image path: video_0121_0004.png
# Detected: (array([[   2.272705,  690.39465 , 1917.7117  , 1076.3636  ]],
#       dtype=float32), ['road 0.76'])
# Processing:  122
# Image path: video_0122_0004.png
# Detected: (array([[   3.8466187,  713.2853   , 1916.6592   , 1076.6414   ]],
#       dtype=float32), ['road 0.66'])
# Processing:  123
# Image path: video_0123_0001.png
# Detected: (array([[   2.4956055,  676.04297  , 1917.4625   , 1076.657    ]],
#       dtype=float32), ['road 0.75'])
# Processing:  124
# Image path: video_0124_0004.png
# Detected: (array([[   4.3168335,  682.4779   , 1917.0676   , 1076.9766   ],
#        [ 113.22113  ,  677.73315  , 1913.7908   ,  772.46936  ]],
#       dtype=float32), ['road 0.75', 'sidewalk 0.33'])
# Processing:  125
# Image path: video_0125_0007.png
# Detected: (array([[2.6513672e+00, 7.1806818e+02, 1.9174412e+03, 1.0770737e+03],
#        [3.8146973e-01, 7.2910706e+02, 6.8198871e+02, 9.1898242e+02],
#        [1.0470526e+03, 7.3277106e+02, 1.9149076e+03, 8.1254779e+02]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.40', 'sidewalk 0.36'])
# Processing:  126
# Image path: video_0126_0010.png
# Detected: (array([[2.1145020e+00, 7.2303625e+02, 1.4734387e+03, 1.0767576e+03],
#        [9.6035767e-01, 7.3126184e+02, 7.4539954e+02, 9.0130530e+02],
#        [4.1598511e+00, 7.2299780e+02, 1.9139939e+03, 1.0764480e+03]],
#       dtype=float32), ['road 0.52', 'road 0.26', 'sidewalk 0.32'])
# Processing:  127
# Image path: video_0127_0003.png
# Detected: (array([[  14.890381,  712.175   ,  958.92377 , 1074.9589  ],
#        [ 700.1672  ,  704.9292  , 1915.8193  , 1048.087   ]],
#       dtype=float32), ['sidewalk 0.34', 'road 0.42'])
# Processing:  128
# Image path: video_0128_0005.png
# Detected: (array([[ 379.49146,  737.6168 , 1913.3357 , 1077.0466 ]], dtype=float32), ['road 0.45', 'road 0.28'])
# Processing:  129
# Image path: video_0129_0003.png
# Detected: (array([[   6.8862915,  714.4519   , 1915.8059   , 1076.3014   ],
#        [   3.7114563,  805.4465   ,  546.2384   ,  937.2941   ]],
#       dtype=float32), ['road 0.52', 'sidewalk 0.37'])
# Processing:  130
# Image path: video_0130_0003.png
# Detected: (array([[   1.989624,  648.63354 , 1917.5875  , 1076.1492  ],
#        [ 576.9311  ,  719.65295 , 1916.6982  ,  964.6361  ],
#        [ 872.202   ,  743.91235 , 1915.9601  ,  963.6725  ]],
#       dtype=float32), ['road 0.62', 'sidewalk 0.26', 'sidewalk 0.35'])
# Processing:  131
# Image path: video_0131_0002.png
# Detected: (array([[3.2426758e+00, 6.1249774e+02, 1.9167537e+03, 1.0762412e+03],
#        [1.2919617e+00, 6.4881415e+02, 5.9451758e+02, 7.5972882e+02]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.41'])
# Processing:  132
# Image path: video_0132_0001.png
# Detected: (array([[   3.4771729,  617.93945  , 1916.3798   , 1073.7268   ],
#        [ 184.9432   ,  713.15186  ,  715.23206  ,  769.121    ]],
#       dtype=float32), ['road 0.61', 'sidewalk 0.30'])
# Processing:  133
# Image path: video_0133_0002.png
# Detected: (array([[   2.4213867,  519.65857  , 1917.4484   ,  978.931    ],
#        [   2.1115417,  514.9572   ,  998.121    ,  721.6827   ]],
#       dtype=float32), ['road 0.79', 'sidewalk 0.31'])
# Processing:  134
# Image path: video_0134_0007.png
# Detected: (array([[  12.069702,  716.23096 , 1907.4133  , 1076.2727  ],
#        [  41.41191 ,  812.5576  ,  516.38995 ,  954.3285  ],
#        [  43.94162 ,  816.82715 ,  508.7914  ,  915.9536  ]],
#       dtype=float32), ['road 0.58', 'sidewalk 0.41', 'sidewalk 0.27'])
# Processing:  135
# Image path: video_0135_0017.png
# Detected: (array([[   2.3198242,  690.4819   , 1917.5044   , 1076.582    ]],
#       dtype=float32), ['road 0.73'])
# Processing:  136
# Image path: video_0136_0008.png
# Detected: (array([[   4.3826904,  609.5388   , 1914.7384   , 1076.2263   ],
#        [ 151.71356  ,  617.8472   ,  756.317    ,  718.11127  ],
#        [ 900.1691   ,  606.7669   , 1061.1102   ,  667.94037  ]],
#       dtype=float32), ['road 0.52', 'sidewalk 0.51', 'road 0.27'])
# Processing:  137
# Image path: video_0137_0003.png
# Detected: (array([[   3.1796265,  708.85034  , 1916.8369   , 1076.754    ],
#        [1489.7987   ,  714.6196   , 1918.0885   ,  840.8085   ],
#        [   2.4205017,  751.2324   ,  815.44775  ,  844.28406  ]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.28', 'sidewalk 0.26'])
# Processing:  138
# Image path: video_0138_0002.png
# Detected: (array([[3.0114136e+00, 6.2462518e+02, 1.9173232e+03, 1.0724375e+03],
#        [1.3843759e+03, 6.2965320e+02, 1.9185192e+03, 8.0471912e+02],
#        [1.4652710e+00, 6.4285596e+02, 8.7792853e+02, 7.6334766e+02]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.36', 'sidewalk 0.33'])
# Processing:  139
# Image path: video_0139_0004.png
# Detected: (array([[   4.1956787,  625.24646  , 1915.1749   , 1065.958    ]],
#       dtype=float32), ['road 0.41'])
# Processing:  140
# Image path: video_0140_0008.png
# Detected: (array([[   3.9956055,  714.1139   , 1414.0927   , 1075.965    ],
#        [1214.0261   ,  775.2811   , 1918.3145   , 1059.14     ],
#        [1579.8977   ,  777.4345   , 1918.2463   ,  881.1777   ],
#        [   4.831299 ,  712.037    , 1914.722    , 1075.4104   ]],
#       dtype=float32), ['road 0.42', 'sidewalk 0.38', 'sidewalk 0.37', 'road 0.34', 'road 0.30'])
# Processing:  141
# Image path: video_0141_0004.png
# Detected: (array([[   2.6554565,  702.95856  , 1917.3025   , 1077.042    ],
#        [1105.4154   ,  793.71515  , 1919.1249   , 1075.3936   ]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.29'])
# Processing:  142
# Image path: video_0142_0007.png
# Detected: (array([[ 123.67474,  739.2903 , 1907.8921 , 1076.8097 ]], dtype=float32), ['road 0.62'])
# Processing:  143
# Image path: video_0143_0008.png
# Detected: (array([[   3.5828857,  645.2932   , 1917.042    , 1075.6135   ],
#        [  25.154907 ,  699.9133   ,  960.8423   ,  802.5394   ],
#        [  23.303085 ,  706.67053  ,  519.2997   ,  803.0486   ],
#        [1683.1044   ,  708.5761   , 1918.712    ,  832.9274   ]],
#       dtype=float32), ['road 0.71', 'sidewalk 0.28', 'sidewalk 0.30', 'sidewalk 0.26'])
# Processing:  144
# Image path: video_0144_0005.png
# Detected: (array([[2.2652588e+00, 7.0194666e+02, 1.9172633e+03, 1.0771223e+03],
#        [1.3381508e+03, 7.4541754e+02, 1.9186642e+03, 9.5099261e+02],
#        [6.3143921e-01, 6.9750446e+02, 7.1874658e+02, 8.9140289e+02],
#        [6.2249756e-01, 6.9745917e+02, 7.1642047e+02, 8.2217682e+02]],
#       dtype=float32), ['road 0.75', 'sidewalk 0.32', 'sidewalk 0.25', 'sidewalk 0.28'])
# Processing:  145
# Image path: video_0145_0001.png
# Detected: (array([[   3.055481 ,  686.41724  , 1110.7998   , 1077.137    ],
#        [ 947.88885  ,  694.3838   , 1917.9958   , 1074.3861   ],
#        [   3.2832642,  685.72675  , 1916.8386   , 1076.3909   ],
#        [ 977.3881   ,  696.0558   , 1917.4663   ,  789.7219   ]],
#       dtype=float32), ['road 0.50', 'road 0.33', 'sidewalk 0.43', 'sidewalk 0.27'])
# Processing:  146
# Image path: video_0146_0001.png
# Detected: (array([[   1.9677734,  638.9842   , 1917.5956   , 1076.4951   ]],
#       dtype=float32), ['road 0.72'])
# Processing:  147
# Image path: video_0147_0008.png
# Detected: (array([[   2.635437,  762.7169  , 1917.2507  , 1076.6831  ],
#        [1356.5916  ,  764.7637  , 1796.7505  ,  857.234   ]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.30'])
# Processing:  148
# Image path: video_0148_0001.png
# Detected: (array([[   2.873291,  555.51825 , 1917.5165  , 1072.4534  ]],
#       dtype=float32), ['road 0.72'])
# Processing:  149
# Image path: video_0149_0009.png
# Detected: (array([[1.1723022e+00, 5.9233362e+02, 1.9185413e+03, 9.5761731e+02],
#        [3.0219116e+00, 5.8768488e+02, 1.9166489e+03, 1.0645791e+03],
#        [1.3595519e+03, 5.5936621e+02, 1.8913495e+03, 5.9857764e+02]],
#       dtype=float32), ['road 0.37', 'sidewalk 0.28', 'road 0.40'])
# Processing:  150
# Image path: video_0150_0004.png
# Detected: (array([[   3.6254883,  712.05304  , 1916.6918   , 1076.114    ],
#        [ 143.20831  ,  723.7244   , 1762.7891   ,  964.3995   ]],
#       dtype=float32), ['road 0.52', 'sidewalk 0.38'])
# Processing:  151
# Image path: video_0151_0004.png
# Detected: (array([[2.8067017e+00, 6.5924951e+02, 1.9178462e+03, 1.0769924e+03],
#        [7.4047852e-01, 6.5568103e+02, 7.7409845e+02, 9.1360596e+02]],
#       dtype=float32), ['road 0.81', 'sidewalk 0.47'])
# Processing:  152
# Image path: video_0152_0004.png
# Detected: (array([[7.3651123e-01, 6.5513202e+02, 7.7852899e+02, 8.9935638e+02],
#        [3.2863770e+00, 6.5755115e+02, 1.9174822e+03, 1.0761359e+03]],
#       dtype=float32), ['road 0.55', 'sidewalk 0.59'])
# Processing:  153
# Image path: video_0153_0003.png
# Detected: (array([[   2.4840698,  679.5647   , 1916.2336   , 1077.0099   ],
#        [1383.925    ,  716.63214  , 1915.03     ,  941.4228   ]],
#       dtype=float32), ['road 0.75', 'sidewalk 0.51'])
# Processing:  154
# Image path: video_0154_0005.png
# Detected: (array([[   2.2005005,  653.89935  , 1917.2922   , 1076.7571   ]],
#       dtype=float32), ['road 0.78'])
# Processing:  155
# Image path: video_0155_0004.png
# Detected: (array([[   3.9422607,  674.57294  , 1915.6637   , 1075.8785   ]],
#       dtype=float32), ['road 0.53', 'sidewalk 0.29'])
# Processing:  156
# Image path: video_0156_0002.png
# Detected: (array([[   3.1854248,  737.3854   , 1914.716    , 1076.6766   ]],
#       dtype=float32), ['road 0.73'])
# Processing:  157
# Image path: video_0157_0003.png
# Detected: (array([[   2.5947266,  699.208    , 1915.7498   , 1076.7445   ]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.27'])
# Processing:  158
# Image path: video_0158_0001.png
# Detected: (array([[   2.895874,  694.3942  , 1917.4543  , 1076.6292  ],
#        [ 926.15814 ,  696.8652  , 1901.5498  ,  814.5445  ]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.28'])
# Processing:  159
# Image path: video_0159_0002.png
# Detected: (array([[   2.6368408,  659.27356  , 1917.2219   , 1075.8202   ],
#        [  66.87042  ,  659.1446   , 1915.2383   ,  749.7338   ]],
#       dtype=float32), ['road 0.65', 'road 0.31'])
# Processing:  160
# Image path: video_0160_0005.png
# Detected: (array([[   2.0565186,  677.7842   , 1918.3214   , 1077.0016   ],
#        [ 945.53204  ,  677.6507   , 1917.0581   ,  814.25323  ]],
#       dtype=float32), ['road 0.76', 'sidewalk 0.46'])
# Processing:  161
# Image path: video_0161_0004.png
# Detected: (array([[3.5415649e+00, 7.0266595e+02, 1.9173086e+03, 1.0768861e+03],
#        [1.4859924e+00, 7.1609985e+02, 6.7230701e+02, 9.4854822e+02]],
#       dtype=float32), ['road 0.76', 'sidewalk 0.38'])
# Processing:  162
# Image path: video_0162_0004.png
# Detected: (array([[   2.7798462,  712.2671   , 1916.8005   , 1076.4374   ]],
#       dtype=float32), ['road 0.74'])
# Processing:  163
# Image path: video_0163_0004.png
# Detected: (array([[   3.1085205,  622.36664  , 1917.4431   , 1069.0076   ],
#        [ 768.7311   ,  627.1632   , 1500.2689   ,  700.5143   ],
#        [   2.1103058,  661.784    ,  408.89496  ,  714.89056  ],
#        [ 760.17847  ,  605.2172   , 1643.9299   ,  700.31256  ]],
#       dtype=float32), ['road 0.70', 'sidewalk 0.30', 'sidewalk 0.26', 'sidewalk 0.30'])
# Processing:  164
# Image path: video_0164_0005.png
# Detected: (array([[   2.470398,  604.115   , 1917.2803  , 1072.0205  ],
#        [ 874.2656  ,  612.7211  , 1917.9712  ,  964.3017  ],
#        [ 877.2022  ,  606.8248  , 1918.0151  ,  822.08264 ]],
#       dtype=float32), ['road 0.59', 'sidewalk 0.31', 'sidewalk 0.31', 'sidewalk 0.27'])
# Processing:  165
# Image path: video_0165_0004.png
# Detected: (array([[   2.348816,  594.21747 , 1917.8909  , 1075.8726  ],
#        [1517.5625  ,  647.342   , 1919.3442  ,  807.6705  ]],
#       dtype=float32), ['road 0.79', 'sidewalk 0.26'])
# Processing:  166
# Image path: video_0166_0007.png
# Detected: (array([[   2.22583,  653.11835, 1917.524  , 1071.965  ]], dtype=float32), ['road 0.74'])
# Processing:  167
# Image path: video_0167_0003.png
# Detected: (array([[   2.7868652,  699.28     , 1917.4473   , 1077.3556   ],
#        [ 972.4063   ,  688.1576   , 1727.2773   ,  752.1388   ]],
#       dtype=float32), ['road 0.77', 'sidewalk 0.26'])
# Processing:  168
# Image path: video_0168_0004.png
# Detected: (array([[   2.0474854,  677.2329   , 1918.2386   , 1077.2325   ],
#        [  21.952576 ,  697.81744  ,  698.2292   ,  761.9548   ]],
#       dtype=float32), ['road 0.80', 'sidewalk 0.28'])
# Processing:  169
# Image path: video_0169_0001.png
# Detected: (array([[   3.2480469,  680.82825  , 1914.2518   , 1076.8951   ],
#        [ 325.96045  ,  694.0991   ,  788.31604  ,  815.32275  ]],
#       dtype=float32), ['road 0.66', 'sidewalk 0.48'])
# Processing:  170
# Image path: video_0170_0002.png
# Detected: (array([[3.0632324e+00, 6.9061157e+02, 1.9170759e+03, 1.0768514e+03],
#        [1.5740967e+00, 7.0326373e+02, 6.5845447e+02, 8.6042401e+02],
#        [1.1338806e+00, 7.0131232e+02, 6.3890100e+02, 7.8863495e+02]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.45', 'sidewalk 0.31'])
# Processing:  171
# Image path: video_0171_0005.png
# Detected: (array([[2.2510986e+00, 7.0099304e+02, 1.9174912e+03, 1.0770217e+03],
#        [1.3640747e+00, 7.0015332e+02, 1.2478674e+03, 1.0773136e+03],
#        [9.4232629e+02, 7.2401349e+02, 1.8993566e+03, 7.9952557e+02],
#        [1.0939100e+03, 7.5221362e+02, 1.9183378e+03, 1.0767417e+03]],
#       dtype=float32), ['road 0.43', 'road 0.38', 'sidewalk 0.29', 'road 0.26'])
# Processing:  172
# Image path: video_0172_0005.png
# Detected: (array([[   4.616577,  697.7591  , 1915.802   , 1077.5736  ],
#        [ 528.81256 ,  706.555   , 1912.45    , 1077.0422  ]],
#       dtype=float32), ['road 0.49', 'sidewalk 0.26'])
# Processing:  173
# Image path: video_0173_0002.png
# Detected: (array([[   2.2874756,  658.9125   , 1917.434    , 1076.5428   ],
#        [ 955.40814  ,  699.9315   , 1917.5317   ,  864.40906  ],
#        [ 262.16867  ,  660.69574  ,  369.87582  ,  724.957    ],
#        [1064.1038   ,  725.1815   , 1916.2671   ,  863.6703   ]],
#       dtype=float32), ['road 0.59', 'sidewalk 0.29', 'sidewalk 0.31', 'sidewalk 0.34'])
# Processing:  174
# Image path: video_0174_0004.png
# Detected: (array([[2.5415649e+00, 6.7769843e+02, 1.9165571e+03, 1.0764573e+03],
#        [1.0371094e+00, 6.8042377e+02, 1.4323969e+03, 1.0751877e+03]],
#       dtype=float32), ['road 0.51', 'road 0.28'])
# Processing:  175
# Image path: video_0175_0001.png
# Detected: (array([[   3.9833374,  642.432    , 1917.0557   , 1076.2131   ],
#        [1226.0978   ,  699.6694   , 1918.7123   ,  977.3863   ]],
#       dtype=float32), ['road 0.81', 'sidewalk 0.44'])
# Processing:  176
# Image path: video_0176_0007.png
# Detected: (array([[   3.2681885,  709.5216   , 1916.9152   , 1075.2397   ],
#        [   2.4886475,  727.42206  ,  481.5272   ,  780.6402   ]],
#       dtype=float32), ['road 0.56', 'sidewalk 0.36'])
# Processing:  177
# Image path: video_0177_0001.png
# Detected: (array([[2.8378906e+00, 5.7329163e+02, 1.9176152e+03, 1.0760265e+03],
#        [6.5383911e-01, 5.9394147e+02, 7.2646033e+02, 8.2887701e+02],
#        [1.2225342e-01, 5.7168152e+02, 8.5529584e+02, 8.3293176e+02]],
#       dtype=float32), ['road 0.83', 'sidewalk 0.31', 'sidewalk 0.37'])
# Processing:  178
# Image path: video_0178_0002.png
# Detected: (array([[   3.4351807,  633.9568   , 1917.3359   , 1076.0844   ],
#        [  93.624695 ,  644.4098   , 1337.3208   ,  835.171    ]],
#       dtype=float32), ['road 0.71', 'sidewalk 0.44'])
# Processing:  179
# Image path: video_0179_0001.png
# Detected: (array([[2.9245605e+00, 6.1479071e+02, 1.9174341e+03, 1.0757568e+03],
#        [8.8485718e-01, 6.1740662e+02, 6.9482568e+02, 8.8214697e+02]],
#       dtype=float32), ['road 0.58', 'sidewalk 0.37'])
# Processing:  180
# Image path: video_0180_0002.png
# Detected: (array([[   3.4176636,  653.0827   , 1915.3875   , 1075.8342   ],
#        [   1.9284363,  671.7555   ,  824.32715  , 1024.2955   ]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.27'])
# Processing:  181
# Image path: video_0181_0003.png
# Detected: (array([[   4.058777,  710.6688  , 1915.0334  , 1077.079   ],
#        [ 986.3892  ,  710.42145 , 1064.7375  ,  754.9681  ]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.32'])
# Processing:  182
# Image path: video_0182_0005.png
# Detected: (array([[   3.5963745,  632.7234   , 1915.3076   , 1076.0609   ],
#        [   4.9125366,  631.9437   , 1148.3735   , 1062.9551   ]],
#       dtype=float32), ['road 0.44', 'road 0.26'])
# Processing:  183
# Image path: video_0183_0001.png
# Detected: (array([[4.6046753e+00, 6.9377081e+02, 1.9137227e+03, 1.0753965e+03],
#        [1.4023132e+00, 7.1301526e+02, 7.9662512e+02, 9.5865051e+02],
#        [1.2659644e+03, 7.0069958e+02, 1.9187439e+03, 1.0509614e+03]],
#       dtype=float32), ['road 0.39', 'sidewalk 0.33', 'road 0.34', 'sidewalk 0.33'])
# Processing:  184
# Image path: video_0184_0005.png
# Detected: (array([[1.0621683e+03, 6.7646252e+02, 1.9180875e+03, 1.0580295e+03],
#        [1.8466187e+00, 7.1082562e+02, 1.3631799e+03, 1.0768777e+03],
#        [3.6250000e+00, 6.8236353e+02, 1.9164423e+03, 1.0759980e+03]],
#       dtype=float32), ['road 0.35', 'road 0.38', 'sidewalk 0.38'])
# Processing:  185
# Image path: video_0185_0004.png
# Detected: (array([[1.8697510e+00, 5.8588153e+02, 1.7297133e+03, 1.0049953e+03],
#        [9.5334619e+02, 5.8770996e+02, 1.9177717e+03, 9.5180273e+02],
#        [2.6904907e+00, 5.8690881e+02, 1.9163357e+03, 1.0709584e+03],
#        [1.2702332e+00, 5.9820978e+02, 6.4307605e+02, 6.7010602e+02]],
#       dtype=float32), ['road 0.41', 'road 0.27', 'road 0.29', 'sidewalk 0.27', 'sidewalk 0.35'])
# Processing:  186
# Image path: video_0186_0003.png
# Detected: (array([[   3.1437378,  665.6522   , 1916.8484   , 1076.663    ],
#        [1054.1826   ,  669.5176   , 1918.3186   , 1039.8751   ]],
#       dtype=float32), ['road 0.68', 'sidewalk 0.52'])
# Processing:  187
# Image path: video_0187_0008.png
# Detected: (array([[   3.1276855,  684.10834  , 1916.4021   , 1076.5708   ],
#        [1253.9569   ,  704.25006  , 1918.7828   ,  966.4996   ],
#        [1401.2446   ,  749.78235  , 1918.0881   ,  966.4784   ]],
#       dtype=float32), ['road 0.72', 'sidewalk 0.31', 'sidewalk 0.35'])
# Processing:  188
# Image path: video_0188_0004.png
# Detected: (array([[   3.2409668,  708.0334   , 1916.8318   , 1073.3954   ]],
#       dtype=float32), ['road 0.55'])
# Processing:  189
# Image path: video_0189_0003.png
# Detected: (array([[  22.65393,  658.8583 , 1917.4667 , 1075.0514 ],
#        [ 272.27197,  734.7457 ,  435.29456,  848.13416]], dtype=float32), ['road 0.79', 'sidewalk 0.41'])
# Processing:  190
# Image path: video_0190_0010.png
# Detected: (array([[   2.9331665,  710.61     , 1917.418    , 1076.9756   ],
#        [   2.4478455,  741.84796  ,  624.9634   ,  802.76276  ]],
#       dtype=float32), ['road 0.69', 'sidewalk 0.28'])
# Processing:  191
# Image path: video_0191_0003.png
# Detected: (array([[3.3101196e+00, 7.0099146e+02, 1.9179148e+03, 1.0772155e+03],
#        [1.3135376e+00, 7.0004291e+02, 7.6644684e+02, 9.4409711e+02]],
#       dtype=float32), ['road 0.79', 'sidewalk 0.46'])
# Processing:  192
# Image path: video_0192_0004.png
# Detected: (array([[1.8103027e+00, 6.9890509e+02, 1.5292529e+03, 1.0765476e+03],
#        [9.5318420e+02, 7.0602563e+02, 1.8351237e+03, 1.0328854e+03],
#        [9.4041748e+02, 7.0975146e+02, 1.5308577e+03, 1.0380226e+03]],
#       dtype=float32), ['road 0.79', 'sidewalk 0.32', 'sidewalk 0.36'])
# Processing:  193
# Image path: video_0193_0002.png
# Detected: (array([[   2.706665,  646.15436 , 1917.3224  , 1069.4572  ],
#        [ 339.7105  ,  661.19354 , 1507.2476  ,  723.57074 ],
#        [   4.2052  ,  641.211   , 1568.3077  ,  726.0589  ]],
#       dtype=float32), ['road 0.77', 'sidewalk 0.28', 'sidewalk 0.28'])
# Processing:  194
# Image path: video_0194_0017.png
# Detected: (array([[   4.1899414,  731.04987  , 1914.5905   , 1077.3047   ],
#        [  20.081055 ,  791.0173   ,  597.5566   ,  963.7275   ]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.43'])
# Processing:  195
# Image path: video_0195_0001.png
# Detected: (array([[   2.5249023,  655.0166   , 1916.0575   , 1074.943    ]],
#       dtype=float32), ['road 0.67'])
# Processing:  196
# Image path: video_0196_0005.png
# Detected: (array([[2.7577515e+00, 6.1959351e+02, 1.9175667e+03, 1.0753976e+03],
#        [9.7387695e-01, 6.6323145e+02, 6.1597345e+02, 8.6101892e+02],
#        [1.2668488e+01, 6.6236682e+02, 6.1782996e+02, 7.2000232e+02]],
#       dtype=float32), ['road 0.77', 'sidewalk 0.28', 'sidewalk 0.30'])
# Processing:  197
# Image path: video_0197_0005.png
# Detected: (array([[   3.0404663,  637.5548   , 1916.2336   , 1074.651    ]],
#       dtype=float32), ['road 0.77'])
# Processing:  198
# Image path: video_0198_0002.png
# Detected: (array([[   2.727234 ,  674.0427   , 1916.8962   , 1076.4248   ],
#        [1538.3298   ,  768.9439   , 1918.4978   , 1019.2115   ],
#        [   1.9837036,  669.6117   ,  868.34357  ,  784.8408   ]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.40', 'sidewalk 0.29'])
# Processing:  199
# Image path: video_0199_0017.png
# Detected: (array([[   2.8103027,  680.06274  , 1273.9668   , 1075.1189   ],
#        [   3.668457 ,  678.8614   , 1913.2883   , 1076.1106   ],
#        [ 979.75366  ,  683.3498   , 1112.6416   ,  754.4953   ]],
#       dtype=float32), ['road 0.42', 'road 0.37', 'sidewalk 0.29'])
# Processing:  200
# Image path: video_0200_0005.png
# Detected: (array([[ 408.4793 ,  731.45215, 1916.396  , 1076.9661 ],
#        [ 796.1177 ,  728.1701 ,  891.4286 ,  786.03827],
#        [ 778.57214,  728.38745,  891.16504,  803.1327 ]], dtype=float32), ['road 0.57', 'sidewalk 0.39', 'sidewalk 0.27'])
# Processing:  201
# Image path: video_0201_0003.png
# Detected: (array([[ 973.7667   ,  755.57776  , 1915.5419   , 1076.317    ],
#        [   3.2399902,  732.3722   , 1243.5712   , 1076.871    ]],
#       dtype=float32), ['road 0.51', 'sidewalk 0.52'])
# Processing:  202
# Image path: video_0202_0009.png
# Detected: (array([[   3.1052856,  651.70935  , 1916.7798   , 1073.7001   ],
#        [ 819.7056   ,  675.0112   , 1899.8008   ,  740.1173   ]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.26'])
# Processing:  203
# Image path: video_0203_0003.png
# Detected: (array([[   8.369568,  689.0751  , 1577.0349  , 1075.9375  ]],
#       dtype=float32), ['road 0.41', 'road 0.31'])
# Processing:  204
# Image path: video_0204_0002.png
# Detected: (array([[   2.9314575,  658.4607   , 1917.0984   , 1076.1569   ],
#        [ 896.75854  ,  672.2483   , 1360.9299   ,  768.7904   ]],
#       dtype=float32), ['road 0.73', 'sidewalk 0.26'])
# Processing:  205
# Image path: video_0205_0002.png
# Detected: (array([[   3.3718262,  693.5131   , 1916.5458   , 1076.6038   ]],
#       dtype=float32), ['road 0.72'])
# Processing:  206
# Image path: video_0206_0001.png
# Detected: (array([[1.4362793e+00, 7.0848553e+02, 1.1817936e+03, 1.0765376e+03],
#        [9.6412561e+02, 7.7065552e+02, 1.9173224e+03, 1.0741809e+03],
#        [3.0078125e+00, 6.9824689e+02, 1.9163618e+03, 1.0762164e+03]],
#       dtype=float32), ['road 0.58', 'sidewalk 0.52', 'road 0.25'])
# Processing:  207
# Image path: video_0207_0001.png
# Detected: (array([[1.5202026e+00, 7.4344574e+02, 1.3198723e+03, 1.0772505e+03],
#        [9.0683569e+02, 7.4054889e+02, 1.9168723e+03, 1.0685576e+03]],
#       dtype=float32), ['road 0.71', 'sidewalk 0.29'])
# Processing:  208
# Image path: video_0208_0005.png
# Detected: (array([[1.8629150e+00, 7.2760583e+02, 1.2813633e+03, 1.0766971e+03],
#        [9.5468396e+02, 7.5126538e+02, 1.9179066e+03, 1.0656931e+03],
#        [1.1349290e+03, 7.9283209e+02, 1.4147822e+03, 8.8250995e+02]],
#       dtype=float32), ['road 0.65', 'sidewalk 0.43', 'sidewalk 0.29'])
# Processing:  209
# Image path: video_0209_0003.png
# Detected: (array([[   2.3787842,  666.34863  , 1917.5681   , 1075.2949   ]],
#       dtype=float32), ['road 0.75'])
# Processing:  210
# Image path: video_0210_0006.png
# Detected: (array([[ 196.76959,  713.8388 , 1904.3821 , 1076.6526 ]], dtype=float32), ['road 0.40', 'sidewalk 0.26', 'road 0.32'])
# Processing:  211
# Image path: video_0211_0003.png
# Detected: (array([[ 2.7656250e+00,  7.0492114e+02,  1.9160691e+03,  1.0773053e+03],
#        [ 1.3288574e+00,  7.1192926e+02,  7.4689038e+02,  9.5312640e+02],
#        [-6.0943604e-02,  7.0780548e+02,  7.3753650e+02,  8.4214423e+02]],
#       dtype=float32), ['road 0.68', 'sidewalk 0.37', 'sidewalk 0.53'])
# Processing:  212
# Image path: video_0212_0007.png
# Detected: (array([[2.4400635e+00, 6.8305701e+02, 1.9172427e+03, 1.0758990e+03],
#        [9.3920789e+02, 6.9736310e+02, 1.9170765e+03, 1.0675693e+03],
#        [1.4452515e+00, 6.8380182e+02, 1.1292402e+03, 1.0753760e+03]],
#       dtype=float32), ['road 0.50', 'road 0.27', 'sidewalk 0.34'])
# Processing:  213
# Image path: video_0213_0003.png
# Detected: (array([[   3.3343506,  671.58734  , 1916.6816   , 1075.7996   ],
#        [  37.30017  ,  685.7994   , 1208.9733   ,  805.96844  ]],
#       dtype=float32), ['road 0.62', 'sidewalk 0.26'])
# Processing:  214
# Image path: video_0214_0001.png
# Detected: (array([[   3.50177,  680.1041 , 1916.8376 , 1076.4666 ],
#        [ 283.75784,  683.0652 ,  825.94495,  750.75195],
#        [ 991.9591 ,  714.2859 , 1918.1039 ,  760.3773 ]], dtype=float32), ['road 0.68', 'sidewalk 0.37', 'sidewalk 0.27'])
# Processing:  215
# Image path: video_0215_0005.png
# Detected: (array([[2.7777100e+00, 6.5484985e+02, 1.9174723e+03, 1.0764612e+03],
#        [9.5471826e+02, 6.5547430e+02, 1.9147832e+03, 8.1023065e+02],
#        [1.4467773e+00, 6.8319794e+02, 6.2690204e+02, 9.3411530e+02]],
#       dtype=float32), ['road 0.78', 'sidewalk 0.46', 'sidewalk 0.25'])
# Processing:  216
# Image path: video_0216_0002.png
# Detected: (array([[2.3400269e+00, 6.1883063e+02, 1.9178154e+03, 1.0759893e+03],
#        [1.2261300e+03, 6.8132086e+02, 1.9193434e+03, 7.7921234e+02],
#        [1.0400391e+00, 7.0009473e+02, 4.9174741e+02, 7.7809692e+02]],
#       dtype=float32), ['road 0.82', 'sidewalk 0.36', 'sidewalk 0.38'])
# Processing:  217
# Image path: video_0217_0007.png
# Detected: (array([[2.6708374e+00, 5.8748901e+02, 1.9179038e+03, 1.0481783e+03],
#        [1.3388977e+00, 5.9570752e+02, 9.5949011e+02, 7.6830518e+02]],
#       dtype=float32), ['road 0.83', 'sidewalk 0.53'])
# Processing:  218
# Image path: video_0218_0005.png
# Detected: (array([[   4.7525024,  672.5947   , 1914.655    , 1075.3801   ],
#        [   2.4083252,  966.91223  , 1917.4182   , 1077.0084   ]],
#       dtype=float32), ['road 0.47', 'sidewalk 0.26'])
# Processing:  219
# Image path: video_0219_0002.png
# Detected: (array([[2.8464355e+00, 6.8929602e+02, 1.9173992e+03, 1.0772820e+03],
#        [8.4762573e-01, 7.1268896e+02, 5.7870654e+02, 9.0613306e+02],
#        [1.0371676e+03, 7.0520624e+02, 1.9155126e+03, 8.0167218e+02]],
#       dtype=float32), ['road 0.82', 'sidewalk 0.51', 'sidewalk 0.36'])
# Processing:  220
# Image path: video_0220_0002.png
# Detected: (array([[1.8043213e+00, 6.2924127e+02, 1.5138274e+03, 1.0421292e+03],
#        [2.5642700e+00, 6.2226385e+02, 1.9140662e+03, 1.0726497e+03]],
#       dtype=float32), ['road 0.41', 'road 0.37'])
# Processing:  221
# Image path: video_0221_0009.png
# Detected: (array([[7.5491333e-01, 6.0070807e+02, 3.4560544e+02, 7.3635040e+02],
#        [1.9298096e+00, 5.1378790e+02, 1.9168058e+03, 9.8021429e+02],
#        [8.6676025e-01, 5.1247400e+02, 1.0335076e+03, 9.6938757e+02]],
#       dtype=float32), ['road 0.40', 'sidewalk 0.45', 'road 0.33', 'road 0.36'])
